# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('/content/Customer_Call.xlsx')

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            1
# Phone_Number         2
# Address              0
# Paying Customer      0
# Do_Not_Contact       4
# Not_Useful_Column    0
# dtype: int64

# %%
df['Do_Not_Contact'].value_counts()
# Out:
# Do_Not_Contact
# No     9
# N      8
# Yes    3
# Y      1
# Name: count, dtype: int64

# %%
df = df.fillna({'Do_Not_Contact':0})

# %%
df['Do_Not_Contact'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].map({'No':0,'Yes':1,'N':0,'Y':1})

# %%
df['Paying Customer'].value_counts()
# Out:
# Paying Customer
# Yes    11
# No      3
# N       3
# Y       3
# N/a     1
# Name: count, dtype: int64

# %%
df = df.fillna({'Paying Customer':0})

# %%
df['Paying Customer'].value_counts()
# Out:
# Paying Customer
# Yes    11
# No      3
# N       3
# Y       3
# N/a     1
# Name: count, dtype: int64

# %%
df['Paying Customer']=df['Paying Customer'].map({'No':0,'Yes':1,'N':0,'Y':1})

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            1
# Phone_Number         2
# Address              0
# Paying Customer      0
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
df['Not_Useful_Column'].value_counts()
# Out:
# Not_Useful_Column
# True     12
# False     9
# Name: count, dtype: int64

# %%
df.drop('Not_Useful_Column',axis=1,inplace=True)

# %%
df.sample()
# Out:
#     CustomerID First_Name Last_Name Phone_Number          Address  \
# 17        1018      Clark      Kent   7066950392  3498 Super Lane
#
#     Paying Customer  Do_Not_Contact
# 17              1.0               0

# %%
df[df['Do_Not_Contact']==1]
# Out:
#     CustomerID First_Name Last_Name  Phone_Number  \
# 1         1002       Abed     Nadir  123/643/9775
# 3         1004     Dwight   Schrute  123-543-2345
# 5         1006        Ron   Swanson  304-762-2467
# 18        1019      Creed    Braton           N/a
#
#                                   Address  Paying Customer  Do_Not_Contact
# 1                     93 West Main Street              0.0               1
# 3   980 Paper Avenue, Pennsylvania, 18503              1.0               1
# 5                        768 City Parkway              1.0               1
# 18                                    N/a              NaN               1

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df['Do_Not_Contact'].value_counts(),labels=['Yes','No'],autopct='%0.2f%%')
plt.show()
