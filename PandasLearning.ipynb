# %%
# Introduction to pandas

# %%
import pandas as pd
import numpy as np

# %%
# Data structure of pandas :
# 1). Series
# 2). DataFrame

# %%
# 1). Series ---> It is 1-d array and it returns only values not column name

a = pd.Series((1,45,78,90))
a
# Out:
# 0     1
# 1    45
# 2    78
# 3    90
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# 2). DataFrame :- It is multi-dimensional array and it returns values with column name

a = {
    'empid' : [1,2,3,4,5],
    'empname' : ['Sam','Rahul','Raj','Gama','Rashu'],
    'department' : ['IT','Operations','IT','IT','Operations'],
    'salary' : [2000,3000,4000,3000,1000],
    'working_hours' : [8,8,9,9,8]
}

df = pd.DataFrame(a)

df
# Out:
#    empid empname  department  salary  working_hours
# 0      1     Sam          IT    2000              8
# 1      2   Rahul  Operations    3000              8
# 2      3     Raj          IT    4000              9
# 3      4    Gama          IT    3000              9
# 4      5   Rashu  Operations    1000              8

# %%
# How can we export our dataframe into csv data ?

df.to_csv('emp_info.csv')  ### to_csv means export your data into csv file

# %%
df.to_csv('new_emp_info.csv', index = False)  ## index = false means it will remove unnamed column

# %%
### How to import csv data using pandas

df = pd.read_csv('/content/new_emp_info.csv')
df
# Out:
#    empid empname  department  salary  working_hours
# 0      1     Sam          IT    2000              8
# 1      2   Rahul  Operations    3000              8
# 2      3     Raj          IT    4000              9
# 3      4    Gama          IT    3000              9
# 4      5   Rashu  Operations    1000              8

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000  100.000000
# mean    44.220000  100.844444
# std     24.878931    1.948380
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  100.922222
# 75%     66.500000  102.000000
# max     84.000000  104.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      100 non-null    float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
# df.head(2)

# %%
df = pd.read_csv('/content/emp_info.csv')
df
# Out:
#    Unnamed: 0  empid empname  department  salary  working_hours
# 0           0      1     Sam          IT    2000              8
# 1           1      2   Rahul  Operations    3000              8
# 2           2      3     Raj          IT    4000              9
# 3           3      4    Gama          IT    3000              9
# 4           4      5   Rashu  Operations    1000              8

# %%
# 2000 sa 5000 range ka bich ka shoes ka data
# best place to visit in masorie ka data

# instantdatascrapper

# %%
df = pd.read_csv('/content/covid_toy.csv')
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
# loc and iloc
# df.loc[row_range, column_name] ---> srtart value include and last value include
# df.iloc[row_range, column_range] ---> start value include and last value exclude

# %%
df.loc[5:10,['age','fever','cough']]
# Out:
#     age       fever   cough
# 5    84  100.844444    Mild
# 6    14  101.000000  Strong
# 7    20  100.844444  Strong
# 8    19  100.000000  Strong
# 9    64  101.000000    Mild
# 10   75  100.844444    Mild

# %%
df.iloc[5:10,[0,2]] = 55

# %%
# df.head(11)

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
# df.head(2)

# %%
df['gender'] = df['gender'].map({'Male':0, 'Female':1})
df['cough'] = df['cough'].map({'Mild':0, 'Strong':1})

# %%
df['has_covid'] = df['has_covid'].map({'Yes':1, 'No':0})

# %%
# df.sample(3)
# Out:
#     age  gender  fever  cough       city  has_covid
# 96   51       1  101.0      1    Kolkata          1
# 52   47       1  100.0      1  Bangalore          1
# 66   51       0  104.0      0    Kolkata          0

# %%
df.drop(columns = ['city'])
# Out:
#     age  gender  fever  cough  has_covid
# 0    60       0  103.0      0          0
# 1    27       0  100.0      0          1
# 2    42       0  101.0      0          0
# 3    31       1   98.0      0          0
# 4    65       1  101.0      0          0
# ..  ...     ...    ...    ...        ...
# 95   12       1  104.0      0          0
# 96   51       1  101.0      1          1
# 97   20       1  101.0      0          0
# 98    5       1   98.0      1          0
# 99   10       1   98.0      1          1
#
# [100 rows x 5 columns]

# %%
df = df.drop(columns = ['city']) #### how to drop or delete one or more columns

# %%
# df.head(2)

# %%
df.sort_index()   ### dort the data
# Out:
#     age  gender  fever  cough  has_covid
# 0    60       0  103.0      0          0
# 1    27       0  100.0      0          1
# 2    42       0  101.0      0          0
# 3    31       1   98.0      0          0
# 4    65       1  101.0      0          0
# ..  ...     ...    ...    ...        ...
# 95   12       1  104.0      0          0
# 96   51       1  101.0      1          1
# 97   20       1  101.0      0          0
# 98    5       1   98.0      1          0
# 99   10       1   98.0      1          1
#
# [100 rows x 5 columns]

# %%
df = df.rename(columns = {'cough':'updated_cough'})

# %%
# df.head(2)

# %%
df['age'] = df['age'].add(10)

# %%
# df.head(2)

# %%
df['fever'] = df['fever'].sub(100)

# %%
# df.head(5)

# %%
df = df.drop(columns = ['age'])

# %%
# df.head(5)
# Out:
#    gender  fever  updated_cough  has_covid
# 0       0    3.0              0          0
# 1       0    0.0              0          1
# 2       0    1.0              0          0
# 3       1   -2.0              0          0
# 4       1    1.0              0          0

# %%
df[['gender','fever']]  #### using this method, we can filter the data
# Out:
#     gender  fever
# 0        0    3.0
# 1        0    0.0
# 2        0    1.0
# 3        1   -2.0
# 4        1    1.0
# ..     ...    ...
# 95       1    4.0
# 96       1    1.0
# 97       1    1.0
# 98       1   -2.0
# 99       1   -2.0
#
# [100 rows x 2 columns]

# %%
df = pd.read_csv('/content/placement.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#    cgpa  resume_score  placed
# 7  6.56          6.29       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.loc[1:2, ['cgpa','resume_score']]
top_left_corner_df
# Out:
#    cgpa  resume_score
# 1  6.17          5.17
# 2  8.27          8.86

# %%
top_left_corner_df = df.iloc[1:4, 1:3]
top_left_corner_df
# Out:
#    resume_score  placed
# 1          5.17       0
# 2          8.86       1
# 3          7.27       1

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty     ### it returns true if there any missing data in dataframe otherwise returns false
b
# Out:
# False

# %%
df.isnull().sum() ##### for check misssing values.
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df = df.dropna()  #### for remove missing row .

# %%
i = df.ndim # no. of axes
i
# Out:
# 2

# %%
print(df.shape) # shape = n(rows), n(columns)
print(df.shape[0])  ### total rows in data
print(df.shape[1])  ### total columns in data
# Out:
# (100, 3)
# 100
# 3

# %%
df.size  # rows count*column count
# Out:
# 300

# %%
df.values # get a numpy array for df
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = 'resume_score', ascending=False)
p
# Out:
#     cgpa  resume_score  placed
# 69  8.06          9.06       1
# 2   8.27          8.86       1
# 65  6.04          8.75       0
# 38  6.00          8.72       0
# 17  7.81          8.71       1
# ..   ...           ...     ...
# 1   6.17          5.17       0
# 41  8.68          5.15       1
# 13  8.50          5.09       1
# 87  5.62          5.05       0
# 94  8.01          4.95       1
#
# [100 rows x 3 columns]

# %%
# x = df.astype(int) # type conversion
df['cgpa'] = df['cgpa'].astype(int)

# %%
# df.head(3)
# Out:
#    cgpa  resume_score  placed
# 0     8          6.52       1
# 1     6          5.17       0
# 2     8          8.86       1

# %%
df['cgpa'] = df['cgpa'].astype(str)

# %%
df.dtypes
# Out:
# cgpa             object
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['cgpa'] = df['cgpa'].astype(int)

# %%
df['cgpa']
# Out:
# 0     12
# 1     10
# 2     12
# 3     10
# 4     11
#       ..
# 95    10
# 96    12
# 97    10
# 98    12
# 99    10
# Name: cgpa, Length: 100, dtype: int64

# %%
# t = df.add(4)
# print(t)
df['cgpa'] = df['cgpa'].add(4)
print(df['cgpa'])
# Out:
# 0     12
# 1     10
# 2     12
# 3     10
# 4     11
#       ..
# 95    10
# 96    12
# 97    10
# 98    12
# 99    10
# Name: cgpa, Length: 100, dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            13.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
g = df.filter(items = ['cgpa','placed'])
g

df[['cgpa','placed']]
# Out:
#     cgpa  placed
# 0   8.14       1
# 1   6.17       0
# 2   8.27       1
# 3   6.88       1
# 4   7.52       1
# ..   ...     ...
# 95  6.33       0
# 96  8.23       1
# 97  6.65       0
# 98  8.14       1
# 99  6.09       0
#
# [100 rows x 2 columns]

# %%
s = df.filter(items = [5,6], axis = 0)  ### axis = 0 means row wise operation
s
# Out:
#    cgpa  resume_score  placed
# 5  8.77          6.19       1
# 6  5.34          7.09       0

# %%
t = df.filter(like = '5', axis = 0)
t
# Out:
#     cgpa  resume_score  placed
# 5   8.77          6.19       1
# 15  8.88          5.93       1
# 25  7.76          5.68       1
# 35  8.07          7.48       1
# 45  8.10          5.44       1
# 50  8.22          6.74       1
# 51  6.54          7.39       0
# 52  5.90          7.50       0
# 53  6.00          7.16       0
# 54  5.92          7.18       0
# 55  6.94          6.87       1
# 56  6.13          6.43       0
# 57  6.34          7.21       0
# 58  6.47          7.37       0
# 59  5.95          7.57       0
# 65  6.04          8.75       0
# 75  6.34          7.94       1
# 85  6.72          5.46       0
# 95  6.33          6.38       0

# %%
df.groupby('placed').size()
# Out:
# placed
# 0    50
# 1    50
# dtype: int64
