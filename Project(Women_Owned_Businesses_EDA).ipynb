# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/women_owned_business_survey_dataset.csv')

# %% [markdown]
# **We will start by checking our dataframe and creating a cleaned dataset to move forward for further analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Respondent_ID                  73 non-null     int64
#  1   Business_Age_Years             73 non-null     int64
#  2   Industry                       73 non-null     object
#  3   Business_Stage                 73 non-null     object
#  4   Annual_Revenue_USD             73 non-null     int64
#  5   Profitability_Status           73 non-null     object
#  6   Primary_Financial_Challenge    73 non-null     object
#  7   Access_to_Credit_Issue         73 non-null     object
#  8   Loan_Application_Status        73 non-null     object
#  9   Loan_Rejection_Reason          58 non-null     object
#  10  Funding_Sources_Used           73 non-null     object
#  11  Desired_Funding_Amount_USD     73 non-null     int64
# ...

# %%
# there are 15 missing values in Loan_Rejection_Reason, let's resolve it
df.isnull().sum()
# Out:
# Respondent_ID                     0
# Business_Age_Years                0
# Industry                          0
# Business_Stage                    0
# Annual_Revenue_USD                0
# Profitability_Status              0
# Primary_Financial_Challenge       0
# Access_to_Credit_Issue            0
# Loan_Application_Status           0
# Loan_Rejection_Reason            15
# Funding_Sources_Used              0
# Desired_Funding_Amount_USD        0
# Barrier_to_Funding                0
# Use_of_Technology                 0
# Digital_Skills_Level              0
# Product_Development_Challenge     0
# Market_Access_Issue               0
# Support_Programs_Awareness        0
# Training_Needs                    0
# Confidence_in_Growth              0
# Required_Resources                0
# Location                          0
# dtype: int64

# %%
df['Loan_Rejection_Reason'].value_counts()
# Out:
# Loan_Rejection_Reason
# Lack of Collateral     18
# Lengthy Process        14
# Limited Awareness      13
# High Interest Rates    13
# Name: count, dtype: int64

# %%
df[df['Loan_Rejection_Reason'].isna()]
# Out:
#     Respondent_ID  Business_Age_Years         Industry Business_Stage  \
# 0               1                   6          Fashion           Idea
# 8               9                   6      Handicrafts         Growth
# 9              10                   9          Fashion    Early-stage
# 12             13                  10         Services           Idea
# 18             19                   7      Handicrafts           Idea
# 27             28                   1          Fashion    Established
# 29             30                   4         Services           Idea
# 31             32                  11  Health & Beauty         Growth
# 34             35                  12      Handicrafts         Growth
# 35             36                  11           Retail           Idea
# 39             40                  10  Health & Beauty         Growth
# 47             48                  14          Fashion    Early-stage
# ...
